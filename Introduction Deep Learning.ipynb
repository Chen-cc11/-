# %% [markdown]
# #### Ups and downs of Deep Learning

# %% [markdown]
# **Perceptron**:linear model
# **Multi-layer perceptron**: be similar to DNN today
# **Backpropagation**:3 hidden layers is not helpful
# **RBM initialization**:(breaakthrough)

# %% [markdown]
# **Step 1**:define a set of function  --**Neural Network**
# **Step 2**:goodness of function
# **Step 3**:pick the best function

# %% [markdown]
# Fully Connect Feedforward Network

# %% [markdown]
# All network neurons known:network is a function.Input vector->output vector
# else:only given network structure,define ~~a function set~~.

# %% [markdown]
# **Neuron**-logistic regression
# **Neural Network**-Different connection leads to different network structures.
# **Network parameter**:all the weights and biases in the "neurons"

# %% [markdown]
# Input Layer /Output Layer /Hidden Layers
# Deep = Many hidden layers

# %% [markdown]
# Matrix Operation
# using parallel computing techniques to speed up matrix operation
# Feature extractor replacing feature engineering
#
# Output Layer = Multi-class Classifier-Softmax()
# Each dimension represents the confidence of a digit.

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Hidden Layers + Output Layer =A function set containing the candidates for the items.

# %% [markdown]
# You need to decide the network structure to let a good function in your function set.
# : Trial and Error + Intuition

# %% [markdown]
# CNN：Convolutional NeuralNetwork

# %% [markdown]
# #### goodness of function
# cross entropy
# Total loss ;for all training data
# Find a function in function set that minimizes total loss L
# Find the network parameters that minimize total loss L
# Gradient Descent

# %% [markdown]
# Backpropagation:an efficient way to compute differentiation in neural network
